# %% [markdown]
# # Урок 4. Объяснение свойств вещества на основе МКТ
#
# ```{admonition} Чему научимся
# :class: tip
# * объяснить любое свойство газа, жидкости или твёрдого тела через движение
#   и взаимодействие молекул;
# * предсказать, как поведёт себя вещество, зная лишь расположение его молекул;
# * отличить объяснение «почему» от простого описания «что происходит».
# ```
#
# ## 1. От описания к объяснению
#
# В предыдущем уроке было показано, как расположены молекулы в трёх состояниях.
# В настоящем уроке по этой картине **предсказываются свойства** веществ, что уже
# является настоящей работой физика.
#
# Схема рассуждения всякий раз одна и та же:
#
# ```{admonition} Как объяснять свойства через МКТ
# :class: important
# 1. Как расположены молекулы: далеко друг от друга или вплотную?
# 2. Как они движутся: свободно летят, перескакивают или только колеблются?
# 3. Насколько сильно взаимодействуют на таком расстоянии?
# 4. **Отсюда** следует свойство.
# ```
#
# Проверим данную схему на каждом свойстве. Модель из предыдущего урока приведена ниже;
# к ней можно возвращаться, если потребуется что-либо перепроверить.

# %%
from phys import sim
sim.states()

# %% [markdown]
# ## 2. Разбираем свойства по очереди
#
# ### Почему газ занимает весь сосуд
#
# Молекулы газа разбросаны далеко: в воздухе расстояние между ними примерно в одиннадцать
# раз больше их собственного размера. Притяжение на такой дистанции почти не работает,
# и удерживать молекулы нечем. Движутся же они быстро и беспорядочно. Поэтому каждая
# летит в произвольном направлении, пока не столкнётся со стенкой.
#
# **Вывод:** газ не сохраняет ни формы, ни объёма и занимает весь предоставленный объём.
#
# ### Почему жидкость сохраняет объём, но не форму
#
# Молекулы жидкости расположены вплотную, притяжение велико и не даёт им разлететься.
# Поэтому объём сохраняется. Однако к своему месту молекула не привязана: она
# колеблется рядом с соседями и перескакивает дальше.
#
# **Вывод:** объём сохраняется, форма нет. Слои свободно скользят друг по другу, жидкость
# течёт и принимает форму сосуда.
#
# ### Почему твёрдое тело сохраняет и форму, и объём
#
# В твёрдом теле молекулы находятся в узлах решётки и колеблются, не покидая своих мест.
# При попытке их раздвинуть включается притяжение, при попытке сблизить они отталкиваются.
#
# **Вывод:** и форма, и объём сохраняются.
#
# ### Почему газ легко сжать, а жидкость и твёрдое тело — нет
#
# Сжать вещество означает сблизить молекулы. В газе между ними много пустоты, которая
# и убирается при сжатии. В жидкости и твёрдом теле молекулы уже находятся на расстоянии
# $r_0$, где любое сближение вызывает резкий рост отталкивания.
#
# **Вывод:** газ сжимается легко, жидкость и твёрдое тело практически не сжимаются.
#
# ```{admonition} Сводка: одно и то же вещество, разные свойства
# :class: important
# | Свойство | Газ | Жидкость | Твёрдое тело |
# |---|---|---|---|
# | Сохраняет объём | нет | **да** | **да** |
# | Сохраняет форму | нет | нет | **да** |
# | Легко сжимается | **да** | нет | нет |
# | Течёт | **да** | **да** | нет |
# | Причина | молекулы далеко и почти не взаимодействуют | молекулы вплотную, но перескакивают | молекулы в узлах решётки, только колеблются |
# ```
#
# ## 3. Проверка схемы на новых свойствах
#
# Хорошая теория объясняет и то, о чём речи ещё не было. Попробуйте ответить
# самостоятельно, прежде чем открывать разбор.

# %%
from phys import quiz
quiz.reveal(
    "Почему газы гораздо легче жидкостей? Плотность воздуха 1,29 кг/м³, "
    "воды 1000 кг/м³, то есть в 775 раз меньше.",
    "Молекулы воздуха и воды по массе отличаются всего в полтора раза "
    "(29 против 18 масс водорода). Следовательно, дело не в массе молекул, а в том, "
    "<b>сколько их помещается в единице объёма</b>. В воде молекулы стоят вплотную, "
    "а в воздухе расстояние между ними в 11 раз больше, поэтому на каждую приходится "
    "объём в 11³ ≈ 1300 раз больший. Отсюда и следует разница в плотности.",
)

# %%
quiz.reveal(
    "Почему диффузия в газах идёт за секунды, в жидкостях за часы, "
    "а в твёрдых телах за годы?",
    "Чтобы вещества перемешались, молекула должна перебраться на новое место. "
    "В газе она свободно летит и ничем не связана, поэтому перемешивание происходит быстро. "
    "В жидкости молекула зажата соседями: чтобы перескочить, ей нужно дождаться "
    "удачного толчка, поэтому процесс идёт медленно. В твёрдом теле молекула находится "
    "в узле решётки и почти никогда его не покидает, поэтому диффузия занимает годы. "
    "Опыт со свинцовой и золотой пластинами это подтвердил: заметное проникновение "
    "обнаружили лишь через пять лет.",
)

# %%
quiz.reveal(
    "Задача. Вода и водяной пар при одной и той же "
    "температуре 100 °C различаются расположением молекул. Что можно сказать "
    "об их свойствах?",
    "Молекулы одни и те же, и движутся они одинаково быстро, поскольку температура равна. "
    "Различие только в расположении: в воде молекулы расположены вплотную и притягиваются, "
    "в паре разошлись примерно на 12 своих размеров и почти не взаимодействуют. "
    "Отсюда все различия: пар занимает весь сосуд и легко сжимается, вода сохраняет "
    "объём и не сжимается. Далее будет показано, что у пара при этом больше и внутренняя "
    "энергия, поскольку на то, чтобы растащить молекулы, пришлось затратить энергию.",
)

# %% [markdown]
# ## 4. Численный опыт: во сколько раз газ «пустее» жидкости
#
# Определим, какую долю объёма занимают сами молекулы в воде и в воздухе.

# %%
import numpy as np
import matplotlib.pyplot as plt
from phys import style

style.use()
m_H = 1.66e-27
razmer = 3e-10                      # характерный размер молекулы, м

def dolya_zanyatogo_obyoma(plotnost, otn_massa):
    """Какую часть объёма занимают сами молекулы."""
    m0 = otn_massa * m_H
    V0 = m0 / plotnost                          # объём, приходящийся на молекулу
    V_molekuly = razmer ** 3                    # объём самой молекулы
    return V_molekuly / V0

for nazvanie, rho, otn in [("вода", 1000, 18), ("лёд", 900, 18),
                           ("воздух", 1.29, 29), ("водяной пар (100 °C)", 0.6, 18)]:
    dolya = dolya_zanyatogo_obyoma(rho, otn)
    print(f"{nazvanie:22s} молекулы занимают {dolya * 100:6.2f} % объёма")

# %% [markdown]
# В воде и во льду молекулы занимают почти весь объём, поэтому сжимать нечего. В воздухе
# на молекулы приходится меньше десятой доли процента, а всё остальное составляет пустота.
# Таково числовое выражение того, что ранее объяснялось словами.
#
# :::{admonition} Копнуть глубже: откуда берётся атмосферное давление
# :class: dropdown
# Проверим теорию на прочность. Давление воздуха известно из опыта и равно примерно
# $10^5$ Па. Выясним, способна ли молекулярная картина дать это число, не используя
# его заранее.
#
# Давление создают удары молекул о стенку. Пусть в единице объёма их $n$ штук, масса
# каждой $m$, скорость $v$. Точный подсчёт даёт формулу
#
# $$p = \frac{1}{3}\,n\,m\,v^2 .$$
#
# Тройка в знаменателе появляется потому, что движение идёт по трём направлениям,
# а на выбранную стенку давит только одно из них. Все три величины справа известны:
# число молекул в кубометре вычислялось на предыдущих уроках, масса молекулы воздуха равна
# 29 массам водорода, скорость теплового движения при комнатной температуре составляет
# около 500 м/с.

# %%
n = 2.5e25            # молекул в кубометре воздуха
m = 29 * 1.66e-27     # масса молекулы воздуха, кг
v = 500               # скорость теплового движения, м/с

p = n * m * v**2 / 3

print(f"Расчёт по молекулярной картине: {p:.2e} Па")
print(f"Измеренное атмосферное давление: 1.0e+05 Па")

# %% [markdown]
# Совпадение полное, притом что ни одна величина в расчёте к давлению отношения
# не имела. Взяты число молекул, их масса и скорость их движения, а получена сила,
# с которой воздух давит на ладонь.
#
# Именно таким образом проверяют теорию: не объясняют задним числом уже известный факт,
# а независимо вычисляют число, которое могло бы и не совпасть.
# :::
#
# ## 5. Опыт своими руками: свойства на столе
#
# ```{admonition} Опыт 1. Жидкость сохраняет объём, но не форму
# :class: opyt
# **Что нужно:** мензурка, несколько сосудов разной формы (стакан, банка, бутылка,
# тарелка), вода.
#
# **Что делать:** отмерьте мензуркой 100 мл воды и перелейте в стакан. Затем из стакана
# перелейте в банку, потом в бутылку, потом в тарелку. Каждый раз возвращайте воду
# в мензурку и проверяйте объём.
#
# **Результат:** форма меняется каждый раз, объём остаётся 100 мл.
# Проделайте то же с кубиком льда: он не меняет ни формы, ни объёма.
# ```
#
# ```{admonition} Опыт 2. Газ занимает весь предоставленный объём
# :class: opyt
# **Что нужно:** воздушный шарик, пластиковая бутылка, горячая и холодная вода.
#
# **Что делать:** наденьте ненадутый шарик на горлышко пустой бутылки. Поставьте бутылку
# в миску с горячей водой на минуту, затем переставьте в холодную.
#
# **Что увидите:** в горячей воде шарик надувается, в холодной сдувается.
# Воздух при этом не добавлялся: при нагревании молекулы движутся быстрее,
# и газ занимает больший объём. Это задание есть и в учебнике (§ 4, задание 3).
# ```
#
# ## 6. Задачи
#
# **Задача 1.** Объясните на основе МКТ, почему запах разлитых духов чувствуется
# по всей комнате, а разлитая вода остаётся лужей на полу.

# %%
quiz.reveal(
    "Показать разбор задачи 1",
    "Молекулы духов, испарившись, становятся газом: расстояния между ними велики, "
    "притяжение не действует, и они разлетаются по всей комнате. Молекулы воды в луже "
    "остаются жидкостью: они притягиваются друг к другу достаточно сильно, чтобы "
    "удерживаться вместе, поэтому вода сохраняет объём и растекается лишь по полу. "
    "Следует отметить, что часть воды всё-таки испаряется и тоже расходится по комнате, "
    "поэтому лужа со временем высыхает.",
)

# %% [markdown]
# **Задача 2.** Почему твёрдые тела и жидкости не разлетаются, хотя их молекулы
# непрерывно движутся?

# %%
quiz.reveal(
    "Показать разбор задачи 2",
    "Движению противостоит притяжение. В твёрдом теле и жидкости молекулы "
    "находятся на расстоянии около r₀, где притяжение велико, и энергии теплового "
    "движения не хватает, чтобы его преодолеть. Молекула колеблется или перескакивает, "
    "но остаётся среди соседей. В газе же энергия движения пересиливает, поэтому там молекулы "
    "действительно разлетаются.",
)

# %% [markdown]
# ## 7. Задача на оценку
#
# **Оцените, во сколько раз увеличится объём воды, если её молекулы разлетятся
# на расстояние, в 11 раз превышающее их размеры, то есть если вода станет газом.**

# %%
quiz.numeric(
    "Во сколько раз увеличится объём?",
    answer=1331, unit="раз", tol=0.15,
    explain="Расстояние между молекулами вырастет в 11 раз, а объём на каждую молекулу "
            "растёт как куб расстояния: 11³ = 1331 раз. Точный ответ для воды при 100 °C составляет "
            "около 1700 раз, то есть оценка по порядку величины верна.",
)

# %% [markdown]
# ## 8. Проверьте себя

# %%
quiz.choice(
    "Почему газ легко сжать, а жидкость практически нет?",
    [
        "Молекулы газа легче молекул жидкости",
        "В газе между молекулами много свободного места, а в жидкости они стоят вплотную",
        "Газ не имеет собственной формы, а жидкость имеет",
        "Молекулы газа меньше по размеру, чем молекулы жидкости",
    ],
    correct=1,
    explain="Сжать вещество означает сблизить молекулы. В газе расстояния между ними "
            "примерно в 10 раз больше размеров самих молекул, и сжатие просто уменьшает "
            "пустые промежутки. В жидкости молекулы уже находятся на расстоянии r₀, "
            "и при малейшем сближении резко возрастают силы отталкивания.<br><br>"
            "Масса и размер молекул здесь не играют роли: в водороде молекулы легчайшие, "
            "и он всё равно сжимается как обычный газ.",
)

# %%
quiz.choice(
    "Плотность водяного пара при 100 °C в 1700 раз меньше плотности воды. Почему?",
    [
        "Молекулы пара легче молекул воды",
        "В паре молекул меньше, часть из них исчезает",
        "В паре те же молекулы, но расстояния между ними примерно в 12 раз больше",
        "Молекулы пара уменьшаются в размерах",
    ],
    correct=2,
    explain="Молекула воды одна и та же в любом состоянии: она не становится легче, не исчезает "
            "и не уменьшается. Меняется только расстояние между молекулами: в 12 раз "
            "по длине, а следовательно, в 12³ ≈ 1700 раз по объёму.",
)

# %% [markdown]
# ```{admonition} Посмотреть
# :class: seealso
# * **Павел Виктор. Урок 14 (осн). Три состояния вещества** (свойства газов, жидкостей
#   и твёрдых тел объясняются у доски именно так, как в настоящем уроке):
#   [RuTube](https://rutube.ru/video/dd3a4bd36f4d26d80a3f8dcc4bd22fee/)
# * [GetAClass — Физика в опытах и экспериментах](https://getaclass.ru/).
#
# Зеркало: [канал Павла Виктора на RuTube](https://rutube.ru/channel/39163190/).
# ```
#
# ## 9. Домашнее задание
#
# 1. **Учебник:** § 2, вопрос 3. Объясните свойства веществ в разных агрегатных
#    состояниях на основе МКТ.
# 2. **Объясните с точки зрения МКТ:**
#    а) почему воздух в шинах приходится подкачивать, а воду в системе отопления нет;
#    б) почему газ приходится хранить в баллонах, а бензин можно в открытой канистре;
#    в) почему лёд не растекается, а вода растекается.
# 3. **Посчитайте.** Плотность гелия 0,18 кг/м³, масса его атома равна 4 массам водорода.
#    Найдите расстояние между атомами гелия и сравните с размером атома.
# 4. **Со звёздочкой.** В баллоне сжатый воздух под давлением 150 атмосфер. Оцените
#    среднее расстояние между молекулами в нём и сравните с обычным воздухом.

# %%
quiz.reveal(
    "Показать ответ к задаче со звёздочкой",
    "Плотность газа при постоянной температуре пропорциональна давлению, следовательно, "
    "в баллоне молекул в 150 раз больше в том же объёме. Объём на одну молекулу "
    "уменьшился в 150 раз, а расстояние в ∛150 ≈ 5,3 раза. "
    "В обычном воздухе расстояние составляет около 11 размеров молекулы, в баллоне "
    "примерно 11 / 5,3 ≈ 2 размера. Молекулы сблизились, но всё ещё не вплотную, "
    "поэтому сжатый воздух остаётся газом и его можно сжимать дальше.",
)

# %% [markdown]
# Схема «расположение плюс движение» объяснила все свойства трёх состояний.
# Однако у самого твёрдого состояния есть две разновидности, и различаются они как раз
# расположением частиц. На следующем уроке рассматривается данный вопрос.
