# %% [markdown]
# # Урок 26. Закон сохранения и превращения энергии в тепловых процессах
#
# ## 1. Механическая энергия сохраняется не всегда
#
# В 7 классе был сформулирован закон сохранения механической энергии: сумма кинетической
# и потенциальной энергий тела остаётся постоянной, если на него не действуют силы трения
# и сопротивления. Данная оговорка существенна. Мяч, брошенный вверх, возвращается с прежней
# скоростью только в пустоте, тогда как в воздухе часть его энергии «пропадает». Санки,
# скатившись с горы, останавливаются на ровном месте, и их кинетическая энергия исчезает.
#
# Ответ на вопрос о том, куда переходит эта энергия, был получен ещё в уроке 9: она переходит
# во внутреннюю энергию. Санки и снег под ними нагреваются, как и воздух за мячом. Свинцовый
# шар, упавший на плиту, потерял механическую энергию, и ровно на столько же возросла
# внутренняя энергия шара и плиты.
#
# ## 2. Полная энергия и изолированная система
#
# ```{admonition} Закон сохранения и превращения энергии
# :class: important
# **Полной энергией** системы тел называют сумму их механической энергии и внутренней энергии.
#
# Систему, на которую не действуют внешние силы ($A = 0$) и которая не участвует в теплообмене
# с окружающими телами ($Q = 0$), называют **изолированной**.
#
# Во всех явлениях, происходящих в природе, энергия не возникает из ничего и не исчезает:
# она лишь **переходит от одного тела к другому или превращается из одного вида в другой**.
# Полная энергия изолированной системы остаётся постоянной.
# ```
#
# Если же система не является изолированной, её внутренняя энергия изменяется ровно на ту
# величину, которая передана ей в форме теплоты и работы:
#
# $$\Delta U = Q + A_{\text{внеш}},$$
#
# где $Q$ — полученное количество теплоты, $A_{\text{внеш}}$ — работа внешних сил над системой.
# Когда работу совершает сама система (например, газ толкает поршень), её внутренняя энергия
# уменьшается на величину этой работы. Данное соотношение представляет собой закон сохранения
# энергии для тепловых процессов, и все формулы темы являются лишь его частными случаями.
#
# ## 3. Закон в действии
#
# Рассмотрим пройденную тему ещё раз и убедимся, что каждый урок был посвящён частному
# случаю данного закона.
#
# | Явление | Что во что переходит |
# |---|---|
# | Трение, удар (урок 9) | механическая энергия → внутренняя |
# | Теплопередача (уроки 10, 13) | внутренняя энергия горячего тела → внутренняя энергия холодного; $Q_{\text{отд}} = Q_{\text{пол}}$ |
# | Сгорание топлива (урок 17) | химическая энергия топлива → внутренняя энергия продуктов горения |
# | Плавление, испарение (уроки 18, 21) | подводимая теплота → потенциальная энергия взаимодействия молекул |
# | Тепловой двигатель (уроки 24–25) | внутренняя энергия газа → механическая работа плюс теплота холодильнику: $Q_1 = A + Q_2$ |
#
# Уравнение теплового баланса, КПД, расчёт теплоты плавления представляют собой один и тот же
# учёт энергии, записанный для различных случаев.
#
# ```{admonition} Кто открыл закон
# :class: note
# К закону сохранения энергии в 1840-х годах независимо пришли несколько учёных: немецкий
# врач Роберт Майер, английский физик Джеймс Джоуль, измеривший, какая работа соответствует
# единице теплоты, и Герман Гельмгольц, давший общую формулировку. Ломоносов за столетие
# до них писал о сохранении «движения» в природе. Джоуль проводил свои первые измерения на пивоварне, которой владел: там имелись и точные термометры, и большие
# ёмкости с водой.
# ```
#
# ## 4. Численный опыт: энергия не пропадает, а перетекает
#
# Проследим за энергией стального шарика, брошенного с высоты на стальную плиту. Считается,
# что вся теплота, выделившаяся при ударе, остаётся в шарике.

# %%
import numpy as np
import matplotlib.pyplot as plt
from phys import style

style.use()
m, h, g, c = 0.1, 20, 9.8, 500              # шарик 100 г, высота 20 м, сталь
E0 = m * g * h
t_pad = np.sqrt(2 * h / g)
t = np.linspace(0, t_pad, 100)
Ep = m * g * (h - g * t**2 / 2)                # потенциальная во время падения
Ek = E0 - Ep                                    # кинетическая

fig, ax = style.axes("Время, с", "Энергия, Дж", "Падение шарика: сумма энергий постоянна, а после удара становится внутренней")
ax.plot(t, Ep, label="потенциальная")
ax.plot(t, Ek, label="кинетическая")
ax.plot(t, Ep + Ek, "--", label="полная механическая")
ax.plot([t_pad, t_pad + 0.3], [0, E0], color="#e07a5f", label="внутренняя после удара")
ax.legend()
plt.show()
dt = E0 / (c * m)
print(f"механическая энергия {E0:.1f} Дж целиком переходит во внутреннюю, шарик нагревается на {dt:.2f} °C")

# %% [markdown]
# Шарик нагревается на четыре десятых градуса: такое изменение трудно измерить, но энергия при этом не исчезает. Следовательно, «потери» в физике всегда означают потерю только механической энергии, тогда как полная энергия сохраняется.
#
# ## 5. Опыт своими руками
#
# ```{admonition} Опыт. Куда уходит энергия мяча (учебник, § 14)
# :class: opyt
# **Что нужно:** упругий мяч, линейка или рулетка.
#
# **Что делать:** отпустите мяч с высоты 1 м и измерьте, на какую высоту он подскочит.
# Повторите для второго, третьего отскока.
#
# **Что записать:** высоты отскоков и доли потерянной энергии: каждая высота в процентах
# от предыдущей.
#
# **Что обсудить:** объясните, почему доля потерь на каждом отскоке примерно одна и та же
# и куда уходит механическая энергия. Потрогайте мяч после десятка ударов о пол.
# ```

# %%
# ↓ ваши измерения: высоты отскоков, м
vysoty = [1.00, 0.62, 0.38, 0.24, 0.15]
m_myacha = 0.06     # кг
for h0, h1 in zip(vysoty, vysoty[1:]):
    print(f"с {h0:.2f} м до {h1:.2f} м: сохранилось {h1 / h0 * 100:.0f} % энергии, во внутреннюю ушло {m_myacha * 9.8 * (h0 - h1):.3f} Дж")

# %% [markdown]
# ## 6. Задачи
#
# **Задача 1 (учебник, упражнение 11).** Два тела массой 1 кг каждое движутся навстречу
# со скоростями 2 м/с, сталкиваются и останавливаются. На сколько изменилась внутренняя
# энергия системы?

# %%
from phys import quiz
quiz.numeric("Изменение внутренней энергии, Дж:", answer=4, unit="Дж", tol=0.02,
             explain="Кинетическая энергия каждого тела mv²/2 = 1 · 4 / 2 = 2 Дж, обоих тел 4 Дж. После "
                     "остановки механическая энергия отсутствует: все 4 Дж перешли во внутреннюю энергию тел.")

# %% [markdown]
# **Задача 2 (Марон, № 18).** При теплопередаче газ получил 40 кДж и совершил работу 10 кДж.
# Чему равно изменение его внутренней энергии?

# %%
quiz.numeric("Изменение внутренней энергии, кДж:", answer=30, unit="кДж", tol=0.02,
             explain="Из полученных 40 кДж газ затратил 10 кДж на работу над окружающими телами, а остальные "
                     "30 кДж остались в нём: ΔU = 40 − 10 = 30 кДж. Ответ сборника: 30 кДж.")

# %% [markdown]
# **Задача 3 (Марон, № 19).** Внутренняя энергия газа выросла на 100 кДж, а передано ему
# 400 кДж. Какую работу совершил газ?

# %%
quiz.numeric("Работа газа, кДж:", answer=300, unit="кДж", tol=0.02,
             explain="A = Q − ΔU = 400 − 100 = 300 кДж.")

# %% [markdown]
# **Задача 4 (Марон, № 20).** Внутренняя энергия газа увеличилась на 300 кДж, при этом он
# совершил работу 800 кДж. Сколько энергии передано газу?

# %%
quiz.numeric("Передано газу, МДж:", answer=1.1, unit="МДж", tol=0.02,
             explain="Q = ΔU + A = 300 + 800 = 1100 кДж = 1,1 МДж. Ответ сборника: 1,1 МДж.")

# %% [markdown]
# **Задача 5.** Почему невозможен вечный двигатель, то есть машина, которая совершала бы
# работу, не получая энергии извне?

# %%
quiz.reveal("Показать разбор",
            "Работа представляет собой передачу энергии. Машина, совершающая работу, отдаёт энергию окружающим "
            "телам, и если она не получает энергию извне, её собственная энергия убывает и рано или поздно "
            "исчерпывается. Вечный двигатель нарушал бы закон сохранения энергии, тогда как за двести лет "
            "поисков не было найдено ни одного исключения из этого закона. Патентные ведомства давно "
            "не принимают подобные заявки.")

# %% [markdown]
# ## 7. Проверьте себя

# %%
quiz.choice("Санки скатились с горы и остановились. Их механическая энергия...",
    ["исчезла", "перешла во внутреннюю энергию санок, снега и воздуха", "вернулась на гору",
     "превратилась в потенциальную"], correct=1,
    explain="Вследствие трения о снег и сопротивления воздуха кинетическая энергия перешла во внутреннюю: "
            "полозья, снег и воздух незначительно нагрелись. Полная энергия при этом сохранилась.")

# %%
quiz.choice("Какая система называется изолированной?",
    ["Стоящая неподвижно", "Не обменивающаяся энергией с окружающими телами ни работой, ни теплотой",
     "Находящаяся в вакууме", "Имеющая постоянную температуру"], correct=1,
    explain="Изолированная система не получает и не отдаёт энергию: над ней не совершается работа, "
            "и она не участвует в теплообмене. Её полная энергия остаётся постоянной.")

# %% [markdown]
# ## 8. Домашнее задание
#
# 1. **Устно.** Учебник, § 14, вопросы 1–4.
# 2. **Письменно.** Конспект § 14, включающий формулировку закона сохранения и превращения энергии,
#    определения полной энергии и изолированной системы и один пример превращения механической
#    энергии во внутреннюю.
# 3. **Письменно.** Учебник, § 14, упражнение 11, задачи 2–4.
# 4. **Устно.** Подготовка к контрольной работе. Повторяются определения и формулы § 10–13, 15, 17,
#    20, 22 и 26 по вопросам после параграфов и по карте темы в следующем уроке.
#
# ```{admonition} Посмотреть
# :class: seealso
# * **Павел Виктор. Урок 129 (осн). Комбинированные задачи на тепловые явления**:
#   [RuTube](https://rutube.ru/video/48460494fcddee01560884b2cd58a4ab/)
# * Все уроки темы собраны в [плейлисте «Тепловые явления» на RuTube](https://rutube.ru/plst/449395/).
# ```
